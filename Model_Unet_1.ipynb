# %% [markdown]
# <a href="https://colab.research.google.com/github/serg-kas/Seams-segm/blob/master/Model_Unet_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seams semantic segmentation

# %% [markdown]
# ### Подготовка окружения

# %%
# !git clone https://github.com/serg-kas/Seams-segm
# %cd Seams-segm
# !ls
# Out:
# Cloning into 'Seams-segm'...
# remote: Enumerating objects: 539, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 539 (delta 41), reused 107 (delta 9), pack-reused 381
# Receiving objects: 100% (539/539), 123.89 MiB | 41.85 MiB/s, done.
# Resolving deltas: 100% (96/96), done.
# /content/Seams-segm
# imgs  masks  Model_Unet.ipynb  prep_data.py  README.md	unet.py  utils.py

# %%
# Подключим google disk
from google.colab import drive 
drive.mount('/content/drive')

# Путь к папке с данным
PATH = '/content/drive/MyDrive/my_data/Seams-segm/'

# !ls {PATH}
# Out:
# Mounted at /content/drive
# 00-Unet  00-Unet.h5  out1  out2  test1	test2

# %%
# Импорт библиотек
import numpy as np
import math
import cv2 as cv
import random
import os
import time
#
import utils as u 
import unet
#
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Reshape, GlobalAveragePooling2D, UpSampling2D, AveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras import backend as K        
from keras.callbacks import ReduceLROnPlateau, EarlyStopping 
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.utils import plot_model
#
import albumentations as A
#
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Пути к данным
images_path = "/content/Seams-segm/imgs"
anns_path = "/content/Seams-segm/masks"

# %%
# Создадим списки файлов с путями к ним
img_names= [ os.path.join(images_path, file_name) for file_name in os.listdir(images_path)]
ann_names = [ os.path.join(anns_path, file_name) for file_name in os.listdir(anns_path)]

# %%
# Посмотрим каких размеров картинки в датасете
dict = {}
cur_time = time.time()
for file_name  in img_names:
    img = cv.imread(file_name)
    if str(img.shape) in dict.keys():
        dict[str(img.shape)] += 1
    else:
        dict[str(img.shape)] = 1
    
print("Имеем картинок: {}".format(len(img_names)))
print("Встречаются размеры: {}".format(dict))
print("Время выполнения: ", round(time.time() - cur_time, 2), 'c', sep='')
# Out:
# Имеем картинок: 41
# Встречаются размеры: {'(1024, 1024, 3)': 15, '(1024, 915, 3)': 1, '(964, 1024, 3)': 1, '(767, 1024, 3)': 1, '(1024, 1022, 3)': 1, '(896, 1024, 3)': 1, '(1024, 864, 3)': 1, '(744, 1024, 3)': 1, '(714, 1024, 3)': 1, '(905, 1024, 3)': 1, '(892, 1024, 3)': 1, '(1024, 816, 3)': 1, '(706, 1024, 3)': 1, '(958, 1024, 3)': 1, '(1024, 665, 3)': 1, '(770, 1023, 3)': 1, '(987, 1024, 3)': 1, '(925, 1024, 3)': 2, '(1024, 831, 3)': 1, '(1024, 1013, 3)': 1, '(989, 1024, 3)': 1, '(501, 1024, 3)': 1, '(1024, 953, 3)': 1, '(1024, 929, 3)': 1, '(907, 1024, 3)': 1, '(466, 1023, 3)': 1}
# Время выполнения: 1.07c

# %%
# Соберем информацию о классах разметки сегментации
ann_set = np.array([])
cur_time = time.time()
for file_name  in ann_names:
    ann = cv.imread(file_name,0)
    # print(ann.shape)
    curr_set = np.unique(ann)
    ann_set = np.union1d(ann_set, curr_set)
    
print("Получили классы разметки: {}".format(ann_set))
print("Время выполнения: ", round(time.time() - cur_time, 2), 'c', sep='')
# Out:
# Получили классы разметки: [  0. 255.]
# Время выполнения: 0.69c

# %%
# Классы сегментации
# 0 - швы
# 255 - плитка (кирпич, доска)
classes = [0, 255]

# %%
# Посмотрим несколько случайных картинок из тренировочной выборки.
# Швы из разметки выделим КРАСНЫМ цветом.
n = 6
fig, axs = plt.subplots(1, n, figsize=(25, 10))  

n_files = random.choices(img_names, k=n) 

for i,file in enumerate(n_files):                               
  image = cv.imread(file)
  image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  ann = cv.imread(os.path.join(anns_path, os.path.basename(file)), 0) 
    
  ones = np.ones((ann.shape[0], ann.shape[1], 3),dtype = np.uint8)
  
  image[:, :, 0] = np.where(ann == 255, image[:, :, 0], ones[:, :, 0] * 255)
  image[:, :, 1] = np.where(ann == 255, image[:, :, 1], ones[:, :, 0] * 0)
  image[:, :, 2] = np.where(ann == 255, image[:, :, 2], ones[:, :, 0] * 0)

  axs[i].axis('off')
  axs[i].imshow(image)             

plt.show()

# %% [markdown]
# **Несолько случайных картинок из датасета. Разметка (швы) прорисована для наглядности красным цветом**

# %% [markdown]
# ### Функция генератор данных

# %%
# Размеры, к которым приводим изображение для нейронки
img_height = 512
img_width = 512

# %%
# Функция - генератор данных
def generate_data(batchsize):
    # Объявляем аугментацию
    transform = A.Compose([
        A.Resize(height=img_height, width=img_width),
        A.HorizontalFlip(p=0.5),
        A.OneOf([
            A.RandomCrop(int(img_height * 0.5), int(img_width * 0.5), p=1),
            A.RandomCrop(int(img_height * 0.75), int(img_width * 0.75), p=1),
            A.RandomCrop(int(img_height * 0.9), int(img_width * 0.9), p=1),
        ], p=0.9),
        A.Resize(height=img_height, width=img_width),
        A.RandomBrightnessContrast(p=0.5),
        A.HueSaturationValue(p=0.5),
        A.OneOf([
            A.MotionBlur(blur_limit=15, p=1),
            A.Blur(blur_limit=15, p=1),
        ], p=0.2),
    ])

    x_data = []
    y_data = []
    batchcount = 0
    while True:
        # Берем картинку
        file_name = random.choice(img_names)
        curr_image = cv.imread(file_name)

        # Делаем коррекцию контраста
        curr_image = u.autocontrast(curr_image)

        # Переходим к RGB
        curr_image = cv.cvtColor(curr_image, cv.COLOR_BGR2RGB)

        # Берем аннотацию
        curr_ann = cv.imread(os.path.join(anns_path, os.path.basename(file_name)), 0)

        # делаем аугментацию
        transformed = transform(image=curr_image, mask=curr_ann)
        transformed_image = transformed['image']
        transformed_ann = transformed['mask']

        # переходим к диапазону 0 до 1 и отправляем картинку в список
        x_data.append(transformed_image / 255.)

        # классы аннотации переводим ohe и отправляем в список
        y_data.append(u.mask_to_ohe(transformed_ann))

        batchcount += 1
        if batchcount >= batchsize:
            X = np.array(x_data, dtype='float32')
            y = np.array(y_data, dtype='float32')
            yield (X, y)
            x_data = []
            y_data = []
            batchcount = 0

# %%
# Посмотрим несколько подготовленных картинок после предобработки и аугментации
# Швы из разметки выделим КРАСНЫМ цветом.
n = 6
g = generate_data(n)
images, anns = next(g)

fig, axs = plt.subplots(1, n, figsize=(25, 10))  

for i in range(n): 
  
  image = (images[i] * 255).astype(np.uint8)
  ann = u.ohe_to_mask(anns[i]) 
  
  ones = np.ones((ann.shape[0], ann.shape[1], 3),dtype = np.uint8)

  image[:, :, 0] = np.where(ann == 255, image[:, :, 0], ones[:, :, 0] * 255)
  image[:, :, 1] = np.where(ann == 255, image[:, :, 1], ones[:, :, 0] * 0)
  image[:, :, 2] = np.where(ann == 255, image[:, :, 2], ones[:, :, 0] * 0)

  
  axs[i].axis('off')
  axs[i].imshow(image)             

plt.show()

# %% [markdown]
# **Несколько случайных картинок в том виде, как они подаются для обучения нейронки. Разметка (швы) прорисована для наглядности красным цветом**

# %% [markdown]
# ### Unet - создание и предварительное обучение модели

# %%
# Создаем модель
num_classes = len(classes)
modelUnet = unet.unet(num_classes, (img_height, img_width, 3))
# modelUnet.summary()
# plot_model(modelUnet, to_file="/content/modelUnet.png", show_shapes=True)

# %%
# Запускаем обучение
batch_size = 5
history = modelUnet.fit(generate_data(batch_size),steps_per_epoch= 100/batch_size, epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 25s 1s/step - loss: 0.4627 - dice_coef: 0.7519
# Epoch 2/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2983 - dice_coef: 0.8463
# Epoch 3/100
# 20/20 [==============================] - 22s 1s/step - loss: 0.3191 - dice_coef: 0.8198
# Epoch 4/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2776 - dice_coef: 0.8305
# Epoch 5/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2642 - dice_coef: 0.8448
# Epoch 6/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2715 - dice_coef: 0.8469
# Epoch 7/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2642 - dice_coef: 0.8455
# Epoch 8/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2418 - dice_coef: 0.8506
# Epoch 9/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2230 - dice_coef: 0.8685
# Epoch 10/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2269 - dice_coef: 0.8681
# Epoch 11/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2138 - dice_coef: 0.8704
# Epoch 12/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1980 - dice_coef: 0.8856
# Epoch 13/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2096 - dice_coef: 0.8703
# Epoch 14/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2066 - dice_coef: 0.8759
# Epoch 15/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2005 - dice_coef: 0.8844
# Epoch 16/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1991 - dice_coef: 0.8836
# Epoch 17/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2004 - dice_coef: 0.8842
# Epoch 18/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1973 - dice_coef: 0.8838
# Epoch 19/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1928 - dice_coef: 0.8858
# Epoch 20/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1860 - dice_coef: 0.8890
# Epoch 21/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1706 - dice_coef: 0.8971
# Epoch 22/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1876 - dice_coef: 0.8908
# Epoch 23/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1755 - dice_coef: 0.8959
# Epoch 24/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1582 - dice_coef: 0.8989
# Epoch 25/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1888 - dice_coef: 0.8927
# Epoch 26/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1706 - dice_coef: 0.8981
# Epoch 27/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1892 - dice_coef: 0.8901
# Epoch 28/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1542 - dice_coef: 0.9046
# Epoch 29/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1450 - dice_coef: 0.9127
# Epoch 30/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1501 - dice_coef: 0.9105
# Epoch 31/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1672 - dice_coef: 0.9034
# Epoch 32/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1469 - dice_coef: 0.9147
# Epoch 33/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1420 - dice_coef: 0.9155
# Epoch 34/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1551 - dice_coef: 0.9087
# Epoch 35/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1793 - dice_coef: 0.8964
# Epoch 36/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1428 - dice_coef: 0.9089
# Epoch 37/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1491 - dice_coef: 0.9144
# Epoch 38/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1644 - dice_coef: 0.9057
# Epoch 39/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1638 - dice_coef: 0.9032
# Epoch 40/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1428 - dice_coef: 0.9147
# Epoch 41/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1558 - dice_coef: 0.9061
# Epoch 42/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1400 - dice_coef: 0.9149
# Epoch 43/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1489 - dice_coef: 0.9111
# Epoch 44/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1423 - dice_coef: 0.9147
# Epoch 45/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1331 - dice_coef: 0.9197
# Epoch 46/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1400 - dice_coef: 0.9168
# Epoch 47/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1459 - dice_coef: 0.9157
# Epoch 48/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1431 - dice_coef: 0.9126
# Epoch 49/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1348 - dice_coef: 0.9193
# Epoch 50/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1553 - dice_coef: 0.9088
# Epoch 51/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1462 - dice_coef: 0.9130
# Epoch 52/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1794 - dice_coef: 0.8944
# Epoch 53/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1439 - dice_coef: 0.9122
# Epoch 54/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1571 - dice_coef: 0.9046
# Epoch 55/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1328 - dice_coef: 0.9214
# Epoch 56/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1311 - dice_coef: 0.9211
# Epoch 57/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1412 - dice_coef: 0.9189
# Epoch 58/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1365 - dice_coef: 0.9152
# Epoch 59/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1543 - dice_coef: 0.9095
# Epoch 60/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1508 - dice_coef: 0.9106
# Epoch 61/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1401 - dice_coef: 0.9156
# Epoch 62/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1496 - dice_coef: 0.9084
# Epoch 63/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1501 - dice_coef: 0.9151
# Epoch 64/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1281 - dice_coef: 0.9221
# Epoch 65/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1526 - dice_coef: 0.9103
# Epoch 66/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1345 - dice_coef: 0.9205
# Epoch 67/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1505 - dice_coef: 0.9126
# Epoch 68/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1560 - dice_coef: 0.9094
# Epoch 69/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1558 - dice_coef: 0.9027
# Epoch 70/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1540 - dice_coef: 0.9141
# Epoch 71/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1503 - dice_coef: 0.9079
# Epoch 72/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1319 - dice_coef: 0.9188
# Epoch 73/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1378 - dice_coef: 0.9217
# Epoch 74/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1382 - dice_coef: 0.9148
# Epoch 75/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1546 - dice_coef: 0.9084
# Epoch 76/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1338 - dice_coef: 0.9215
# Epoch 77/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1066 - dice_coef: 0.9337
# Epoch 78/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1469 - dice_coef: 0.9163
# Epoch 79/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1254 - dice_coef: 0.9256
# Epoch 80/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1357 - dice_coef: 0.9181
# Epoch 81/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1345 - dice_coef: 0.9216
# Epoch 82/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1348 - dice_coef: 0.9183
# Epoch 83/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1442 - dice_coef: 0.9144
# Epoch 84/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1217 - dice_coef: 0.9270
# Epoch 85/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1269 - dice_coef: 0.9235
# Epoch 86/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1227 - dice_coef: 0.9276
# Epoch 87/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1358 - dice_coef: 0.9187
# Epoch 88/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1236 - dice_coef: 0.9240
# Epoch 89/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1255 - dice_coef: 0.9280
# Epoch 90/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1403 - dice_coef: 0.9163
# Epoch 91/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1199 - dice_coef: 0.9280
# Epoch 92/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1321 - dice_coef: 0.9249
# Epoch 93/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1233 - dice_coef: 0.9230
# Epoch 94/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1338 - dice_coef: 0.9242
# Epoch 95/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1223 - dice_coef: 0.9250
# Epoch 96/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1497 - dice_coef: 0.9122
# Epoch 97/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1364 - dice_coef: 0.9180
# Epoch 98/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1296 - dice_coef: 0.9238
# Epoch 99/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1291 - dice_coef: 0.9245
# Epoch 100/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1183 - dice_coef: 0.9299

# %%
# График точности обучения
plt.plot(history.history['dice_coef'], label='Метрика dice_coef')
plt.xlabel('Эпоха обучения')
plt.legend()
plt.show()

# %% [markdown]
# **Результат пробного обучения неплохой. Видно что потенциал обучения не исчерпан (тренд графика точности смотрит вверх)**

# %%
# Сохраняем модель
model_file = os.path.join(PATH, '00-Unet')
modelUnet.save(model_file, save_format='tf')

model_file = os.path.join(PATH, '00-Unet.h5')
modelUnet.save(model_file)

# !ls {PATH}
# Out:
# 00-Unet  00-Unet.h5

# %% [markdown]
# ### Unet - дообучение

# %%
# !ls {PATH}
# Out:
# 00-Unet  00-Unet.h5  out1  out2  test1	test2

# %%
# Дообучаем
model_file = os.path.join(PATH, '00-Unet')
model = load_model(model_file, custom_objects={'dice_coef':unet.dice_coef})

lr = 0.001
history_list = []

# Определим коллбэки
reduce_lr = ReduceLROnPlateau(monitor='dice_coef', 
                              patience=15, 
                              verbose=1, 
                              factor=0.5, 
                              min_lr=0.000001)
earlystopper = EarlyStopping(patience=30,
                             verbose=1,
                             monitor='dice_coef',
                             restore_best_weights=True)

for N in range(1,5):

  model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=lr), metrics=[unet.dice_coef])
  # model.compile(loss='categorical_crossentropy', optimizer=RMSprop(learning_rate=0.001), metrics=['dice_coef'])


  print('\nТренировка: ', N)

  batch_size = 5
  history = model.fit(generate_data(batch_size),
                      steps_per_epoch= 100/batch_size,
                      epochs=500,
                      verbose=1,
                      callbacks=[reduce_lr,earlystopper])

  history_list.append(history)

  file_number = "%02d" % (N)

  model_file = os.path.join(PATH, file_number + '-Unet')
  model.save(model_file, save_format='tf')

  model_file = os.path.join(PATH, file_number + '-Unet.h5')  
  model.save(model_file)
# Out:
# Тренировка:  1
# Epoch 1/500
# 20/20 [==============================] - 25s 1s/step - loss: 0.1260 - dice_coef: 0.9238 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1327 - dice_coef: 0.9240 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1250 - dice_coef: 0.9237 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1347 - dice_coef: 0.9213 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1222 - dice_coef: 0.9276 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1376 - dice_coef: 0.9171 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1360 - dice_coef: 0.9201 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1133 - dice_coef: 0.9294 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1351 - dice_coef: 0.9208 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1222 - dice_coef: 0.9268 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1160 - dice_coef: 0.9310 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1214 - dice_coef: 0.9303 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1139 - dice_coef: 0.9294 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1233 - dice_coef: 0.9288 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1338 - dice_coef: 0.9203 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1346 - dice_coef: 0.9205 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1239 - dice_coef: 0.9251 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1330 - dice_coef: 0.9213 - lr: 0.0010
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1153 - dice_coef: 0.9314 - lr: 0.0010
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1091 - dice_coef: 0.9319 - lr: 0.0010
# Epoch 21/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1472 - dice_coef: 0.9207
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1472 - dice_coef: 0.9207 - lr: 0.0010
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1380 - dice_coef: 0.9146 - lr: 5.0000e-04
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1275 - dice_coef: 0.9251 - lr: 5.0000e-04
# Epoch 24/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1211 - dice_coef: 0.9243 - lr: 5.0000e-04
# Epoch 25/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1220 - dice_coef: 0.9274 - lr: 5.0000e-04
# Epoch 26/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1065 - dice_coef: 0.9350 - lr: 5.0000e-04
# Epoch 27/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1109 - dice_coef: 0.9335 - lr: 5.0000e-04
# Epoch 28/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1015 - dice_coef: 0.9373 - lr: 5.0000e-04
# Epoch 29/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1198 - dice_coef: 0.9315 - lr: 5.0000e-04
# Epoch 30/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1199 - dice_coef: 0.9243 - lr: 5.0000e-04
# Epoch 31/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1206 - dice_coef: 0.9311 - lr: 5.0000e-04
# Epoch 32/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1217 - dice_coef: 0.9253 - lr: 5.0000e-04
# Epoch 33/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1065 - dice_coef: 0.9358 - lr: 5.0000e-04
# Epoch 34/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1099 - dice_coef: 0.9359 - lr: 5.0000e-04
# Epoch 35/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1131 - dice_coef: 0.9321 - lr: 5.0000e-04
# Epoch 36/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.0909 - dice_coef: 0.9427 - lr: 5.0000e-04
# Epoch 37/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1180 - dice_coef: 0.9334
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1180 - dice_coef: 0.9334 - lr: 5.0000e-04
# Epoch 38/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1254 - dice_coef: 0.9241 - lr: 2.5000e-04
# Epoch 39/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1104 - dice_coef: 0.9348 - lr: 2.5000e-04
# Epoch 40/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1262 - dice_coef: 0.9285 - lr: 2.5000e-04
# Epoch 41/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1004 - dice_coef: 0.9362 - lr: 2.5000e-04
# Epoch 42/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1029 - dice_coef: 0.9382 - lr: 2.5000e-04
# Epoch 43/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1036 - dice_coef: 0.9381 - lr: 2.5000e-04
# Epoch 44/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1025 - dice_coef: 0.9384 - lr: 2.5000e-04
# Epoch 45/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1098 - dice_coef: 0.9359 - lr: 2.5000e-04
# Epoch 46/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1085 - dice_coef: 0.9344 - lr: 2.5000e-04
# Epoch 47/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1075 - dice_coef: 0.9354 - lr: 2.5000e-04
# Epoch 48/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1067 - dice_coef: 0.9376 - lr: 2.5000e-04
# Epoch 49/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.0942 - dice_coef: 0.9424 - lr: 2.5000e-04
# Epoch 50/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1134 - dice_coef: 0.9366 - lr: 2.5000e-04
# Epoch 51/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.0993 - dice_coef: 0.9379 - lr: 2.5000e-04
# Epoch 52/500
# 20/20 [==============================] - ETA: 0s - loss: 0.0982 - dice_coef: 0.9401
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Restoring model weights from the end of the best epoch: 22.
# 20/20 [==============================] - 23s 1s/step - loss: 0.0982 - dice_coef: 0.9401 - lr: 2.5000e-04
# Epoch 52: early stopping
#
# Тренировка:  2
# Epoch 1/500
# 20/20 [==============================] - 25s 1s/step - loss: 0.1235 - dice_coef: 0.9268 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1324 - dice_coef: 0.9234 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1181 - dice_coef: 0.9280 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1168 - dice_coef: 0.9298 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1218 - dice_coef: 0.9288 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1191 - dice_coef: 0.9265 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1268 - dice_coef: 0.9260 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1174 - dice_coef: 0.9295 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1257 - dice_coef: 0.9255 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1222 - dice_coef: 0.9306 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1131 - dice_coef: 0.9317 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1207 - dice_coef: 0.9283 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1205 - dice_coef: 0.9309 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1089 - dice_coef: 0.9326 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1138 - dice_coef: 0.9341 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1091 - dice_coef: 0.9339 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1140 - dice_coef: 0.9332
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1140 - dice_coef: 0.9332 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1022 - dice_coef: 0.9379 - lr: 5.0000e-04
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.0998 - dice_coef: 0.9407 - lr: 5.0000e-04
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1195 - dice_coef: 0.9312 - lr: 5.0000e-04
# Epoch 21/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1157 - dice_coef: 0.9337 - lr: 5.0000e-04
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1093 - dice_coef: 0.9339 - lr: 5.0000e-04
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1055 - dice_coef: 0.9364 - lr: 5.0000e-04
# Epoch 24/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1166 - dice_coef: 0.9312 - lr: 5.0000e-04
# Epoch 25/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1053 - dice_coef: 0.9372 - lr: 5.0000e-04
# Epoch 26/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1071 - dice_coef: 0.9326 - lr: 5.0000e-04
# Epoch 27/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1138 - dice_coef: 0.9351 - lr: 5.0000e-04
# Epoch 28/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1019 - dice_coef: 0.9382 - lr: 5.0000e-04
# Epoch 29/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1089 - dice_coef: 0.9353 - lr: 5.0000e-04
# Epoch 30/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1124 - dice_coef: 0.9338 - lr: 5.0000e-04
# Epoch 31/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1116 - dice_coef: 0.9335 - lr: 5.0000e-04
# Epoch 32/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1099 - dice_coef: 0.9353
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 2.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1099 - dice_coef: 0.9353 - lr: 5.0000e-04
# Epoch 32: early stopping
#
# Тренировка:  3
# Epoch 1/500
# 20/20 [==============================] - 25s 1s/step - loss: 0.1487 - dice_coef: 0.9153 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1211 - dice_coef: 0.9229 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1228 - dice_coef: 0.9267 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1257 - dice_coef: 0.9247 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1279 - dice_coef: 0.9246 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1216 - dice_coef: 0.9237 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1288 - dice_coef: 0.9279 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1246 - dice_coef: 0.9259 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1144 - dice_coef: 0.9310 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1222 - dice_coef: 0.9271 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1092 - dice_coef: 0.9322 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1197 - dice_coef: 0.9311 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1283 - dice_coef: 0.9231 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1265 - dice_coef: 0.9292 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1092 - dice_coef: 0.9329 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1231 - dice_coef: 0.9315
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1231 - dice_coef: 0.9315 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1023 - dice_coef: 0.9340 - lr: 5.0000e-04
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1200 - dice_coef: 0.9323 - lr: 5.0000e-04
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1064 - dice_coef: 0.9334 - lr: 5.0000e-04
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1066 - dice_coef: 0.9344 - lr: 5.0000e-04
# Epoch 21/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1107 - dice_coef: 0.9362 - lr: 5.0000e-04
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1014 - dice_coef: 0.9369 - lr: 5.0000e-04
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1079 - dice_coef: 0.9360 - lr: 5.0000e-04
# Epoch 24/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1123 - dice_coef: 0.9344 - lr: 5.0000e-04
# Epoch 25/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1056 - dice_coef: 0.9365 - lr: 5.0000e-04
# Epoch 26/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1072 - dice_coef: 0.9399 - lr: 5.0000e-04
# Epoch 27/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1124 - dice_coef: 0.9321 - lr: 5.0000e-04
# Epoch 28/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1008 - dice_coef: 0.9382 - lr: 5.0000e-04
# Epoch 29/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1003 - dice_coef: 0.9386 - lr: 5.0000e-04
# Epoch 30/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1020 - dice_coef: 0.9410 - lr: 5.0000e-04
# Epoch 31/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1019 - dice_coef: 0.9374
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 1.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1019 - dice_coef: 0.9374 - lr: 5.0000e-04
# Epoch 31: early stopping
#
# Тренировка:  4
# Epoch 1/500
# 20/20 [==============================] - 25s 1s/step - loss: 0.1344 - dice_coef: 0.9211 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1186 - dice_coef: 0.9305 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1248 - dice_coef: 0.9258 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1207 - dice_coef: 0.9259 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1123 - dice_coef: 0.9332 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1275 - dice_coef: 0.9255 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1186 - dice_coef: 0.9287 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1241 - dice_coef: 0.9273 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1267 - dice_coef: 0.9231 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1498 - dice_coef: 0.9198 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1381 - dice_coef: 0.9177 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1204 - dice_coef: 0.9304 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1160 - dice_coef: 0.9291 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1163 - dice_coef: 0.9322 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1102 - dice_coef: 0.9324 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1241 - dice_coef: 0.9253 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1353 - dice_coef: 0.9219 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1259 - dice_coef: 0.9265 - lr: 0.0010
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1264 - dice_coef: 0.9247 - lr: 0.0010
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1188 - dice_coef: 0.9283 - lr: 0.0010
# Epoch 21/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1130 - dice_coef: 0.9313 - lr: 0.0010
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1040 - dice_coef: 0.9368 - lr: 0.0010
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1161 - dice_coef: 0.9318 - lr: 0.0010
# Epoch 24/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1325 - dice_coef: 0.9233 - lr: 0.0010
# Epoch 25/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1105 - dice_coef: 0.9348 - lr: 0.0010
# Epoch 26/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1010 - dice_coef: 0.9385
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1010 - dice_coef: 0.9385 - lr: 0.0010
# Epoch 27/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1305 - dice_coef: 0.9296 - lr: 5.0000e-04
# Epoch 28/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1008 - dice_coef: 0.9350 - lr: 5.0000e-04
# Epoch 29/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1041 - dice_coef: 0.9382 - lr: 5.0000e-04
# Epoch 30/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1234 - dice_coef: 0.9299 - lr: 5.0000e-04
# Epoch 31/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1175 - dice_coef: 0.9285 - lr: 5.0000e-04
# Epoch 32/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1093 - dice_coef: 0.9361 - lr: 5.0000e-04
# Epoch 33/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1029 - dice_coef: 0.9375 - lr: 5.0000e-04
# Epoch 34/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1008 - dice_coef: 0.9396 - lr: 5.0000e-04
# Epoch 35/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1038 - dice_coef: 0.9370 - lr: 5.0000e-04
# Epoch 36/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1233 - dice_coef: 0.9294 - lr: 5.0000e-04
# Epoch 37/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1085 - dice_coef: 0.9325 - lr: 5.0000e-04
# Epoch 38/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1269 - dice_coef: 0.9266 - lr: 5.0000e-04
# Epoch 39/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1042 - dice_coef: 0.9349 - lr: 5.0000e-04
# Epoch 40/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1155 - dice_coef: 0.9325 - lr: 5.0000e-04
# Epoch 41/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1085 - dice_coef: 0.9357
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 11.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1085 - dice_coef: 0.9357 - lr: 5.0000e-04
# Epoch 41: early stopping

# %%
#Отображаем график точности в процессе обучения
history_dice = []
for N in range(4):
  history_dice += history_list[N].history['dice_coef']

plt.figure(figsize=(16,5))
plt.plot(history_dice, 
         label='dice_coef')
plt.xlabel('Эпоха обучения')
plt.ylabel('Метрики')
plt.legend()
plt.show()

# %% [markdown]
# ### Предикт и визуализация на обучающих данных

# %%
# !ls {PATH}
# Out:
# 00-Unet     01-Unet	02-Unet     03-Unet	04-Unet     out1  test1
# 00-Unet.h5  01-Unet.h5	02-Unet.h5  03-Unet.h5	04-Unet.h5  out2  test2

# %%
# Загружаем модель
model_file = os.path.join(PATH, '01-Unet')
model = load_model(model_file, custom_objects={'dice_coef':unet.dice_coef})

# %%
# Предикт и визуализация картинок из train
n = 5
fig, axs = plt.subplots(3, n, figsize=(25, 10))  

n_files = random.choices(img_names, k=n) 
for i,file in enumerate(n_files):
    image = cv.imread(file)
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    ann = cv.imread(os.path.join(anns_path, os.path.basename(file)), 0)
    pred= unet.pred_images(model, image, img_height, img_width)
    #
    ones = np.ones((ann.shape[0], ann.shape[1], 3),dtype = np.uint8)
    image_ann = image.copy()
    image_ann[:, :, 0] = np.where(ann == 255, image[:, :, 0], ones[:, :, 0] * 255)
    image_ann[:, :, 1] = np.where(ann == 255, image[:, :, 1], ones[:, :, 0] * 0)
    image_ann[:, :, 2] = np.where(ann == 255, image[:, :, 2], ones[:, :, 0] * 0)
    #
    ones = np.ones((pred.shape[0], pred.shape[1], 3),dtype = np.uint8)
    image_pred = image.copy()
    image_pred[:, :, 0] = np.where(pred == 255, image[:, :, 0], ones[:, :, 0] * 0)
    image_pred[:, :, 1] = np.where(pred == 255, image[:, :, 1], ones[:, :, 0] * 255)
    image_pred[:, :, 2] = np.where(pred == 255, image[:, :, 2], ones[:, :, 0] * 0)

    axs[0,i].axis('off')
    axs[0,i].imshow(image)
    axs[0,i].set_title('original')

    axs[1,i].axis('off')
    axs[1,i].imshow(image_ann)  
    axs[1,i].set_title('annotation')

    axs[2,i].axis('off')
    axs[2,i].imshow(image_pred)
    axs[2,i].set_title(round(unet.dice_coef_np(u.mask_to_ohe(ann), u.mask_to_ohe(pred)), 5))
    
plt.show()

# %% [markdown]
# **Предикт на данных из обучающей выборки**
#
# Первый ряд - оригинальные изображения
#
# Ниже - с визуальзацией разметки (красным)
#
# Третий ряд - предикт модели (визуализация зеленым)

# %% [markdown]
# ### Предикт тестовых изображений с сохранением результатов

# %%
# !ls {PATH}
# Out:
# 00-Unet     01-Unet	02-Unet     03-Unet	04-Unet     out1  test1
# 00-Unet.h5  01-Unet.h5	02-Unet.h5  03-Unet.h5	04-Unet.h5  out2  test2

# %%
# Загружаем модель
model_file = os.path.join(PATH, '01-Unet')
model = load_model(model_file, custom_objects={'dice_coef':unet.dice_coef})

# %%
# Тестовые картинки
test_path = PATH + 'test1'
out_path = PATH + 'out1'

# !ls {test_path}
# Out:
# Paving_simple_colored_7183_diffuse_8K.jpg  Tactile_Paving_6872_diffuse_4K.jpg
# Roofing_corrida_8762_diffuse_4K.jpg	   Tactile_Paving_6872_height_4K.jpg
# Shingles_Hex_8174_diffuse.jpg		   Travertin_yellow_7349_diffuse_8K.jpg
# Stone_blocks_6371_diffuse_16K.jpg	   Wood_decking_5936_diffuse_6K.jpg

# %%
# Создадим список файлов
test_names= [os.path.join(test_path, file_name) for file_name in os.listdir(test_path)]

# %%
# Предикт и визуализация картинок из test
n = len(test_names)
fig, axs = plt.subplots(2, n, figsize=(25, 10))  

for i,file in enumerate(test_names):
    image = cv.imread(file)
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    # 
    pred = unet.pred_images(model, image, img_height, img_width) 
    #
    ones = np.ones((pred.shape[0], pred.shape[1], 3),dtype = np.uint8)
    image_pred = image.copy()
    image_pred[:, :, 0] = np.where(pred == 255, image_pred[:, :, 0], ones[:, :, 0] * 0)
    image_pred[:, :, 1] = np.where(pred == 255, image_pred[:, :, 1], ones[:, :, 0] * 255)
    image_pred[:, :, 2] = np.where(pred == 255, image_pred[:, :, 2], ones[:, :, 0] * 0)

    out_file = os.path.join(out_path, 'out_' + os.path.basename(file))
    print('Сохраняем результат {}'.format(out_file))
    ret = cv.imwrite(out_file, image_pred)
    if ret==False:
      print('Не удалось сохранить: {}'.format(file))

    axs[0,i].axis('off')
    axs[0,i].imshow(image)
    axs[0,i].set_title('original')

    axs[1,i].axis('off')
    axs[1,i].imshow(image_pred)
    axs[1,i].set_title('predict')
    
plt.show()
# Out:
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Tactile_Paving_6872_height_4K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Shingles_Hex_8174_diffuse.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Tactile_Paving_6872_diffuse_4K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Wood_decking_5936_diffuse_6K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Roofing_corrida_8762_diffuse_4K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Travertin_yellow_7349_diffuse_8K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Stone_blocks_6371_diffuse_16K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Paving_simple_colored_7183_diffuse_8K.jpg

# %% [markdown]
# **Предикт на тестовых данных,  то есть на данных, которые нейронка не видела в процессе обучения**
