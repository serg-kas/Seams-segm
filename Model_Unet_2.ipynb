# %% [markdown]
# <a href="https://colab.research.google.com/github/serg-kas/Seams-segm/blob/master/Model_Unet_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seams semantic segmentation

# %% [markdown]
# ### Подготовка окружения

# %%
# !git clone https://github.com/serg-kas/Seams-segm
# %cd Seams-segm
# !ls
# Out:
# Cloning into 'Seams-segm'...
# remote: Enumerating objects: 591, done.
# remote: Total 591 (delta 0), reused 0 (delta 0), pack-reused 591
# Receiving objects: 100% (591/591), 126.48 MiB | 41.43 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /content/Seams-segm
# imgs   Model_Unet_1.ipynb  prep_data.py  unet.py
# masks  Model_Unet.ipynb    README.md	 utils.py

# %%
# Подключим google disk
from google.colab import drive 
drive.mount('/content/drive')

# Путь к папке с данным
PATH = '/content/drive/MyDrive/my_data/Seams-segm/'

# !ls {PATH}
# Out:
# Mounted at /content/drive
# out1  out2  test1  test2  Архив-Unet-1

# %%
# Импорт библиотек
import numpy as np
import math
import cv2 as cv
import random
import os
import time
#
import utils as u 
import unet
#
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D
from tensorflow.keras.layers import Reshape, GlobalAveragePooling2D, UpSampling2D, AveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras import backend as K        
from keras.callbacks import ReduceLROnPlateau, EarlyStopping 
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.utils import plot_model
#
import albumentations as A
#
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Пути к данным
images_path = "/content/Seams-segm/imgs"
anns_path = "/content/Seams-segm/masks"

# %%
# Создадим списки файлов с путями к ним
img_names= [ os.path.join(images_path, file_name) for file_name in os.listdir(images_path)]
ann_names = [ os.path.join(anns_path, file_name) for file_name in os.listdir(anns_path)]

# %%
# Посмотрим каких размеров картинки в датасете
dict = {}
cur_time = time.time()
for file_name  in img_names:
    img = cv.imread(file_name)
    if str(img.shape) in dict.keys():
        dict[str(img.shape)] += 1
    else:
        dict[str(img.shape)] = 1
    
print("Имеем картинок: {}".format(len(img_names)))
print("Встречаются размеры: {}".format(dict))
print("Время выполнения: ", round(time.time() - cur_time, 2), 'c', sep='')
# Out:
# Имеем картинок: 41
# Встречаются размеры: {'(925, 1024, 3)': 2, '(1024, 1024, 3)': 15, '(767, 1024, 3)': 1, '(706, 1024, 3)': 1, '(501, 1024, 3)': 1, '(905, 1024, 3)': 1, '(964, 1024, 3)': 1, '(907, 1024, 3)': 1, '(1024, 929, 3)': 1, '(1024, 864, 3)': 1, '(466, 1023, 3)': 1, '(958, 1024, 3)': 1, '(1024, 831, 3)': 1, '(987, 1024, 3)': 1, '(1024, 953, 3)': 1, '(744, 1024, 3)': 1, '(989, 1024, 3)': 1, '(892, 1024, 3)': 1, '(896, 1024, 3)': 1, '(770, 1023, 3)': 1, '(1024, 1022, 3)': 1, '(1024, 665, 3)': 1, '(1024, 1013, 3)': 1, '(1024, 816, 3)': 1, '(1024, 915, 3)': 1, '(714, 1024, 3)': 1}
# Время выполнения: 0.96c

# %%
# Соберем информацию о классах разметки сегментации
ann_set = np.array([])
cur_time = time.time()
for file_name  in ann_names:
    ann = cv.imread(file_name,0)
    # print(ann.shape)
    curr_set = np.unique(ann)
    ann_set = np.union1d(ann_set, curr_set)
    
print("Получили классы разметки: {}".format(ann_set))
print("Время выполнения: ", round(time.time() - cur_time, 2), 'c', sep='')
# Out:
# Получили классы разметки: [  0. 255.]
# Время выполнения: 0.68c

# %%
# Классы сегментации
# 0 - швы
# 255 - плитка (кирпич, доска)
classes = [0, 255]

# %%
# Посмотрим несколько случайных картинок из тренировочной выборки.
# Швы из разметки выделим КРАСНЫМ цветом.
n = 6
fig, axs = plt.subplots(1, n, figsize=(25, 10))  

n_files = random.choices(img_names, k=n) 

for i,file in enumerate(n_files):                               
  image = cv.imread(file)
  image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  ann = cv.imread(os.path.join(anns_path, os.path.basename(file)), 0) 
    
  ones = np.ones((ann.shape[0], ann.shape[1], 3),dtype = np.uint8)
  
  image[:, :, 0] = np.where(ann == 255, image[:, :, 0], ones[:, :, 0] * 255)
  image[:, :, 1] = np.where(ann == 255, image[:, :, 1], ones[:, :, 0] * 0)
  image[:, :, 2] = np.where(ann == 255, image[:, :, 2], ones[:, :, 0] * 0)

  axs[i].axis('off')
  axs[i].imshow(image)             

plt.show()

# %% [markdown]
# **Несолько случайных картинок из датасета. Разметка (швы) прорисована для наглядности красным цветом**

# %% [markdown]
# ### Функция генератор данных

# %%
# Размеры, к которым приводим изображение для нейронки
img_height = 512
img_width = 512

# %%
# Функция - генератор данных
def generate_data(batchsize):
    # Объявляем аугментацию
    transform = A.Compose([
        A.Resize(height=img_height, width=img_width),
        A.HorizontalFlip(p=0.5),
        A.OneOf([
            A.RandomCrop(int(img_height * 0.5), int(img_width * 0.5), p=1),
            A.RandomCrop(int(img_height * 0.75), int(img_width * 0.75), p=1),
            A.RandomCrop(int(img_height * 0.9), int(img_width * 0.9), p=1),
        ], p=0.9),
        A.Resize(height=img_height, width=img_width),
        A.RandomBrightnessContrast(p=0.5),
        A.HueSaturationValue(p=0.5),
        A.OneOf([
            A.MotionBlur(blur_limit=15, p=1),
            A.Blur(blur_limit=15, p=1),
        ], p=0.2),
    ])

    x_data = []
    y_data = []
    batchcount = 0
    while True:
        # Берем картинку
        file_name = random.choice(img_names)
        curr_image = cv.imread(file_name)

        # Делаем коррекцию контраста
        curr_image = u.autocontrast(curr_image)

        # Переходим к RGB
        curr_image = cv.cvtColor(curr_image, cv.COLOR_BGR2RGB)

        # Берем аннотацию
        curr_ann = cv.imread(os.path.join(anns_path, os.path.basename(file_name)), 0)

        # делаем аугментацию
        transformed = transform(image=curr_image, mask=curr_ann)
        transformed_image = transformed['image']
        transformed_ann = transformed['mask']

        # переходим к диапазону 0 до 1 и отправляем картинку в список
        x_data.append(transformed_image / 255.)

        # классы аннотации переводим ohe и отправляем в список
        y_data.append(u.mask_to_ohe(transformed_ann))

        batchcount += 1
        if batchcount >= batchsize:
            X = np.array(x_data, dtype='float32')
            y = np.array(y_data, dtype='float32')
            yield (X, y)
            x_data = []
            y_data = []
            batchcount = 0

# %%
# Посмотрим несколько подготовленных картинок после предобработки и аугментации
# Швы из разметки выделим КРАСНЫМ цветом.
n = 6
g = generate_data(n)
images, anns = next(g)

fig, axs = plt.subplots(1, n, figsize=(25, 10))  

for i in range(n): 
  
  image = (images[i] * 255).astype(np.uint8)
  ann = u.ohe_to_mask(anns[i]) 
  
  ones = np.ones((ann.shape[0], ann.shape[1], 3),dtype = np.uint8)

  image[:, :, 0] = np.where(ann == 255, image[:, :, 0], ones[:, :, 0] * 255)
  image[:, :, 1] = np.where(ann == 255, image[:, :, 1], ones[:, :, 0] * 0)
  image[:, :, 2] = np.where(ann == 255, image[:, :, 2], ones[:, :, 0] * 0)

  
  axs[i].axis('off')
  axs[i].imshow(image)             

plt.show()

# %% [markdown]
# **Несколько случайных картинок в том виде, как они подаются для обучения нейронки. Разметка (швы) прорисована для наглядности красным цветом**

# %% [markdown]
# ### Unet - создание и предварительное обучение модели

# %%
# Создаем модель
num_classes = len(classes)
modelUnet = unet.unet(num_classes, (img_height, img_width, 3))
# modelUnet.summary()
# plot_model(modelUnet, to_file="/content/modelUnet.png", show_shapes=True)

# %%
# Запускаем обучение
batch_size = 5
history = modelUnet.fit(generate_data(batch_size),steps_per_epoch= 100/batch_size, epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 47s 1s/step - loss: 0.3815 - dice_coef: 0.7966
# Epoch 2/100
# 20/20 [==============================] - 21s 1s/step - loss: 0.2924 - dice_coef: 0.8352
# Epoch 3/100
# 20/20 [==============================] - 22s 1s/step - loss: 0.2610 - dice_coef: 0.8565
# Epoch 4/100
# 20/20 [==============================] - 22s 1s/step - loss: 0.2721 - dice_coef: 0.8378
# Epoch 5/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2328 - dice_coef: 0.8754
# Epoch 6/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2401 - dice_coef: 0.8642
# Epoch 7/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2438 - dice_coef: 0.8609
# Epoch 8/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2233 - dice_coef: 0.8761
# Epoch 9/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2393 - dice_coef: 0.8651
# Epoch 10/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2352 - dice_coef: 0.8678
# Epoch 11/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2366 - dice_coef: 0.8611
# Epoch 12/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2145 - dice_coef: 0.8837
# Epoch 13/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2498 - dice_coef: 0.8585
# Epoch 14/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2187 - dice_coef: 0.8709
# Epoch 15/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2280 - dice_coef: 0.8752
# Epoch 16/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2089 - dice_coef: 0.8778
# Epoch 17/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2271 - dice_coef: 0.8698
# Epoch 18/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2013 - dice_coef: 0.8786
# Epoch 19/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2108 - dice_coef: 0.8815
# Epoch 20/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2049 - dice_coef: 0.8844
# Epoch 21/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2012 - dice_coef: 0.8826
# Epoch 22/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1816 - dice_coef: 0.8999
# Epoch 23/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1728 - dice_coef: 0.8996
# Epoch 24/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1895 - dice_coef: 0.8924
# Epoch 25/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.2033 - dice_coef: 0.8795
# Epoch 26/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1984 - dice_coef: 0.8881
# Epoch 27/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1861 - dice_coef: 0.8903
# Epoch 28/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1734 - dice_coef: 0.9007
# Epoch 29/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1847 - dice_coef: 0.8908
# Epoch 30/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1845 - dice_coef: 0.8922
# Epoch 31/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1765 - dice_coef: 0.8951
# Epoch 32/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1509 - dice_coef: 0.9095
# Epoch 33/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1666 - dice_coef: 0.9079
# Epoch 34/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1662 - dice_coef: 0.9009
# Epoch 35/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1787 - dice_coef: 0.9021
# Epoch 36/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1540 - dice_coef: 0.9009
# Epoch 37/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1740 - dice_coef: 0.9049
# Epoch 38/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1732 - dice_coef: 0.9009
# Epoch 39/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1642 - dice_coef: 0.9016
# Epoch 40/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1707 - dice_coef: 0.9018
# Epoch 41/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1484 - dice_coef: 0.9064
# Epoch 42/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1429 - dice_coef: 0.9187
# Epoch 43/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1765 - dice_coef: 0.8959
# Epoch 44/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1769 - dice_coef: 0.8959
# Epoch 45/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1642 - dice_coef: 0.9041
# Epoch 46/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1528 - dice_coef: 0.9074
# Epoch 47/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1234 - dice_coef: 0.9233
# Epoch 48/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1473 - dice_coef: 0.9188
# Epoch 49/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1630 - dice_coef: 0.8994
# Epoch 50/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1468 - dice_coef: 0.9171
# Epoch 51/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1462 - dice_coef: 0.9110
# Epoch 52/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1348 - dice_coef: 0.9196
# Epoch 53/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1473 - dice_coef: 0.9144
# Epoch 54/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1406 - dice_coef: 0.9147
# Epoch 55/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1349 - dice_coef: 0.9191
# Epoch 56/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1540 - dice_coef: 0.9122
# Epoch 57/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1486 - dice_coef: 0.9139
# Epoch 58/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1354 - dice_coef: 0.9166
# Epoch 59/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1347 - dice_coef: 0.9230
# Epoch 60/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1370 - dice_coef: 0.9169
# Epoch 61/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1368 - dice_coef: 0.9188
# Epoch 62/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1394 - dice_coef: 0.9164
# Epoch 63/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1407 - dice_coef: 0.9158
# Epoch 64/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1366 - dice_coef: 0.9204
# Epoch 65/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1302 - dice_coef: 0.9210
# Epoch 66/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1365 - dice_coef: 0.9230
# Epoch 67/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1268 - dice_coef: 0.9261
# Epoch 68/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1276 - dice_coef: 0.9219
# Epoch 69/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1435 - dice_coef: 0.9167
# Epoch 70/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1405 - dice_coef: 0.9159
# Epoch 71/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1435 - dice_coef: 0.9145
# Epoch 72/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1278 - dice_coef: 0.9236
# Epoch 73/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1454 - dice_coef: 0.9146
# Epoch 74/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1172 - dice_coef: 0.9282
# Epoch 75/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1298 - dice_coef: 0.9214
# Epoch 76/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1256 - dice_coef: 0.9238
# Epoch 77/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1350 - dice_coef: 0.9247
# Epoch 78/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1329 - dice_coef: 0.9194
# Epoch 79/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1239 - dice_coef: 0.9271
# Epoch 80/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1244 - dice_coef: 0.9244
# Epoch 81/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1349 - dice_coef: 0.9193
# Epoch 82/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1245 - dice_coef: 0.9262
# Epoch 83/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1360 - dice_coef: 0.9196
# Epoch 84/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1274 - dice_coef: 0.9257
# Epoch 85/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1250 - dice_coef: 0.9250
# Epoch 86/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1304 - dice_coef: 0.9258
# Epoch 87/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1338 - dice_coef: 0.9161
# Epoch 88/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1119 - dice_coef: 0.9328
# Epoch 89/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1116 - dice_coef: 0.9343
# Epoch 90/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1122 - dice_coef: 0.9353
# Epoch 91/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1051 - dice_coef: 0.9345
# Epoch 92/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1362 - dice_coef: 0.9198
# Epoch 93/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1207 - dice_coef: 0.9310
# Epoch 94/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1159 - dice_coef: 0.9291
# Epoch 95/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1148 - dice_coef: 0.9301
# Epoch 96/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1328 - dice_coef: 0.9258
# Epoch 97/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1261 - dice_coef: 0.9232
# Epoch 98/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1189 - dice_coef: 0.9284
# Epoch 99/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1135 - dice_coef: 0.9302
# Epoch 100/100
# 20/20 [==============================] - 23s 1s/step - loss: 0.1223 - dice_coef: 0.9270

# %%
# График точности обучения
plt.plot(history.history['dice_coef'], label='Метрика dice_coef')
plt.xlabel('Эпоха обучения')
plt.legend()
plt.show()

# %% [markdown]
# **Результат пробного обучения неплохой. Видно что потенциал обучения не исчерпан (тренд графика точности смотрит вверх)**

# %%
# Сохраняем модель
model_file = os.path.join(PATH, '00-Unet')
modelUnet.save(model_file, save_format='tf')

model_file = os.path.join(PATH, '00-Unet.h5')
modelUnet.save(model_file)

# !ls {PATH}
# Out:
# 00-Unet  00-Unet.h5  out1  out2  test1	test2  Архив-Unet-1

# %% [markdown]
# ### Unet - дообучение

# %%
# !ls {PATH}
# Out:
# 00-Unet  00-Unet.h5  out1  out2  test1	test2  Архив-Unet-1

# %%
# Дообучаем
model_file = os.path.join(PATH, '00-Unet')
model = load_model(model_file, custom_objects={'dice_coef':unet.dice_coef})

lr = 0.001
history_list = []

# Определим коллбэки
reduce_lr = ReduceLROnPlateau(monitor='dice_coef', 
                              patience=10, 
                              verbose=1, 
                              factor=0.5, 
                              min_lr=0.000001)
earlystopper = EarlyStopping(patience=15,
                             verbose=1,
                             monitor='dice_coef',
                             restore_best_weights=True)

for N in range(1,5):

  model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=lr), metrics=[unet.dice_coef])
  # model.compile(loss='categorical_crossentropy', optimizer=RMSprop(learning_rate=0.001), metrics=['dice_coef'])


  print('\nТренировка: ', N)

  batch_size = 5
  history = model.fit(generate_data(batch_size),
                      steps_per_epoch= 100/batch_size,
                      epochs=500,
                      verbose=1,
                      callbacks=[reduce_lr,earlystopper])

  history_list.append(history)

  file_number = "%02d" % (N)

  model_file = os.path.join(PATH, file_number + '-Unet')
  model.save(model_file, save_format='tf')

  model_file = os.path.join(PATH, file_number + '-Unet.h5')  
  model.save(model_file)
# Out:
# Тренировка:  1
# Epoch 1/500
# 20/20 [==============================] - 24s 1s/step - loss: 0.1186 - dice_coef: 0.9308 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1141 - dice_coef: 0.9310 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 24s 1s/step - loss: 0.1243 - dice_coef: 0.9258 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 24s 1s/step - loss: 0.1304 - dice_coef: 0.9250 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1307 - dice_coef: 0.9241 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1206 - dice_coef: 0.9245 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1250 - dice_coef: 0.9281 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1114 - dice_coef: 0.9301 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1227 - dice_coef: 0.9335 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1284 - dice_coef: 0.9248 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1330 - dice_coef: 0.9184 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1280 - dice_coef: 0.9242 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1214 - dice_coef: 0.9302 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1066 - dice_coef: 0.9343 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1122 - dice_coef: 0.9348 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1137 - dice_coef: 0.9314 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1074 - dice_coef: 0.9337 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1254 - dice_coef: 0.9269 - lr: 0.0010
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1205 - dice_coef: 0.9286 - lr: 0.0010
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1231 - dice_coef: 0.9264 - lr: 0.0010
# Epoch 21/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1211 - dice_coef: 0.9274
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1211 - dice_coef: 0.9274 - lr: 0.0010
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1227 - dice_coef: 0.9269 - lr: 5.0000e-04
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1157 - dice_coef: 0.9314 - lr: 5.0000e-04
# Epoch 24/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1067 - dice_coef: 0.9333 - lr: 5.0000e-04
# Epoch 25/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1134 - dice_coef: 0.9371 - lr: 5.0000e-04
# Epoch 26/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1012 - dice_coef: 0.9354Restoring model weights from the end of the best epoch: 11.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1012 - dice_coef: 0.9354 - lr: 5.0000e-04
# Epoch 26: early stopping
#
# Тренировка:  2
# Epoch 1/500
# 20/20 [==============================] - 26s 1s/step - loss: 0.1295 - dice_coef: 0.9267 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 24s 1s/step - loss: 0.1254 - dice_coef: 0.9219 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1126 - dice_coef: 0.9347 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1258 - dice_coef: 0.9259 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1123 - dice_coef: 0.9313 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1354 - dice_coef: 0.9223 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1116 - dice_coef: 0.9332 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1163 - dice_coef: 0.9319 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1127 - dice_coef: 0.9304 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1281 - dice_coef: 0.9279 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1324 - dice_coef: 0.9220 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1352 - dice_coef: 0.9201 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1356 - dice_coef: 0.9213 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1447 - dice_coef: 0.9137 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1069 - dice_coef: 0.9353 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1191 - dice_coef: 0.9269 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1193 - dice_coef: 0.9282 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1255 - dice_coef: 0.9247 - lr: 0.0010
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1034 - dice_coef: 0.9391 - lr: 0.0010
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1022 - dice_coef: 0.9374 - lr: 0.0010
# Epoch 21/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1068 - dice_coef: 0.9370 - lr: 0.0010
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1042 - dice_coef: 0.9334 - lr: 0.0010
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1061 - dice_coef: 0.9383 - lr: 0.0010
# Epoch 24/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1081 - dice_coef: 0.9328
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1081 - dice_coef: 0.9328 - lr: 0.0010
# Epoch 25/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1019 - dice_coef: 0.9400 - lr: 5.0000e-04
# Epoch 26/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1273 - dice_coef: 0.9267 - lr: 5.0000e-04
# Epoch 27/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1010 - dice_coef: 0.9354 - lr: 5.0000e-04
# Epoch 28/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.0963 - dice_coef: 0.9420 - lr: 5.0000e-04
# Epoch 29/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1014 - dice_coef: 0.9403Restoring model weights from the end of the best epoch: 14.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1014 - dice_coef: 0.9403 - lr: 5.0000e-04
# Epoch 29: early stopping
#
# Тренировка:  3
# Epoch 1/500
# 20/20 [==============================] - 25s 1s/step - loss: 0.1312 - dice_coef: 0.9247 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 24s 1s/step - loss: 0.1179 - dice_coef: 0.9270 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1144 - dice_coef: 0.9309 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1154 - dice_coef: 0.9333 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1081 - dice_coef: 0.9340 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1518 - dice_coef: 0.9147 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1133 - dice_coef: 0.9300 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1244 - dice_coef: 0.9275 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1169 - dice_coef: 0.9315 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1313 - dice_coef: 0.9273 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1268 - dice_coef: 0.9205 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1139 - dice_coef: 0.9317 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1134 - dice_coef: 0.9327 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1155 - dice_coef: 0.9330 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1228 - dice_coef: 0.9273 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1163 - dice_coef: 0.9318
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1163 - dice_coef: 0.9318 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1055 - dice_coef: 0.9377 - lr: 5.0000e-04
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1181 - dice_coef: 0.9297 - lr: 5.0000e-04
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1196 - dice_coef: 0.9276 - lr: 5.0000e-04
# Epoch 20/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1017 - dice_coef: 0.9376 - lr: 5.0000e-04
# Epoch 21/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1103 - dice_coef: 0.9358Restoring model weights from the end of the best epoch: 6.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1103 - dice_coef: 0.9358 - lr: 5.0000e-04
# Epoch 21: early stopping
#
# Тренировка:  4
# Epoch 1/500
# 20/20 [==============================] - 25s 1s/step - loss: 0.1128 - dice_coef: 0.9353 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 24s 1s/step - loss: 0.1149 - dice_coef: 0.9322 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1169 - dice_coef: 0.9308 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1152 - dice_coef: 0.9286 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1050 - dice_coef: 0.9374 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1097 - dice_coef: 0.9351 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1026 - dice_coef: 0.9357 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1081 - dice_coef: 0.9374 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1339 - dice_coef: 0.9238 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1317 - dice_coef: 0.9181 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1117 - dice_coef: 0.9336 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1229 - dice_coef: 0.9271 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1031 - dice_coef: 0.9361 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1128 - dice_coef: 0.9329 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1234 - dice_coef: 0.9291 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1228 - dice_coef: 0.9291 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1152 - dice_coef: 0.9329 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1148 - dice_coef: 0.9299 - lr: 0.0010
# Epoch 19/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1014 - dice_coef: 0.9394 - lr: 0.0010
# Epoch 20/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1008 - dice_coef: 0.9380
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1008 - dice_coef: 0.9380 - lr: 0.0010
# Epoch 21/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1058 - dice_coef: 0.9373 - lr: 5.0000e-04
# Epoch 22/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1084 - dice_coef: 0.9339 - lr: 5.0000e-04
# Epoch 23/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1011 - dice_coef: 0.9381 - lr: 5.0000e-04
# Epoch 24/500
# 20/20 [==============================] - 23s 1s/step - loss: 0.1098 - dice_coef: 0.9371 - lr: 5.0000e-04
# Epoch 25/500
# 20/20 [==============================] - ETA: 0s - loss: 0.1008 - dice_coef: 0.9372Restoring model weights from the end of the best epoch: 10.
# 20/20 [==============================] - 23s 1s/step - loss: 0.1008 - dice_coef: 0.9372 - lr: 5.0000e-04
# Epoch 25: early stopping

# %%
#Отображаем график точности в процессе обучения
history_dice = []
for N in range(4):
  history_dice += history_list[N].history['dice_coef']

plt.figure(figsize=(16,5))
plt.plot(history_dice, 
         label='dice_coef')
plt.xlabel('Эпоха обучения')
plt.ylabel('Метрики')
plt.legend()
plt.show()

# %% [markdown]
# ### Предикт и визуализация на обучающих данных

# %%
# !ls {PATH}
# Out:
# 00-Unet     01-Unet.h5	03-Unet     04-Unet.h5	out1   test2
# 00-Unet.h5  02-Unet	03-Unet.h5  imgs_fs	out2   Архив-Unet-1
# 01-Unet     02-Unet.h5	04-Unet     masks_fs	test1

# %%
# Загружаем модель
model_file = os.path.join(PATH, '02-Unet')
model = load_model(model_file, custom_objects={'dice_coef':unet.dice_coef})

# %%
# Предикт и визуализация картинок из train
n = 5
fig, axs = plt.subplots(3, n, figsize=(25, 10))  

n_files = random.choices(img_names, k=n) 
for i,file in enumerate(n_files):
    image = cv.imread(file)
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    ann = cv.imread(os.path.join(anns_path, os.path.basename(file)), 0)
    pred= unet.pred_images(model, image, img_height, img_width)
    #
    ones = np.ones((ann.shape[0], ann.shape[1], 3),dtype = np.uint8)
    image_ann = image.copy()
    image_ann[:, :, 0] = np.where(ann == 255, image[:, :, 0], ones[:, :, 0] * 255)
    image_ann[:, :, 1] = np.where(ann == 255, image[:, :, 1], ones[:, :, 0] * 0)
    image_ann[:, :, 2] = np.where(ann == 255, image[:, :, 2], ones[:, :, 0] * 0)
    #
    ones = np.ones((pred.shape[0], pred.shape[1], 3),dtype = np.uint8)
    image_pred = image.copy()
    image_pred[:, :, 0] = np.where(pred == 255, image[:, :, 0], ones[:, :, 0] * 0)
    image_pred[:, :, 1] = np.where(pred == 255, image[:, :, 1], ones[:, :, 0] * 255)
    image_pred[:, :, 2] = np.where(pred == 255, image[:, :, 2], ones[:, :, 0] * 0)

    axs[0,i].axis('off')
    axs[0,i].imshow(image)
    axs[0,i].set_title('original')

    axs[1,i].axis('off')
    axs[1,i].imshow(image_ann)  
    axs[1,i].set_title('annotation')

    axs[2,i].axis('off')
    axs[2,i].imshow(image_pred)
    axs[2,i].set_title(round(unet.dice_coef_np(u.mask_to_ohe(ann), u.mask_to_ohe(pred)), 5))
    
plt.show()

# %% [markdown]
# **Предикт на данных из обучающей выборки**
#
# Первый ряд - оригинальные изображения
#
# Ниже - с визуальзацией разметки (красным)
#
# Третий ряд - предикт модели (визуализация зеленым)

# %% [markdown]
# ### Предикт тестовых изображений с сохранением результатов

# %%
# !ls {PATH}
# Out:
# 00-Unet     01-Unet.h5	03-Unet     04-Unet.h5	out1   test2
# 00-Unet.h5  02-Unet	03-Unet.h5  imgs_fs	out2   Архив-Unet-1
# 01-Unet     02-Unet.h5	04-Unet     masks_fs	test1

# %%
# Загружаем модель
model_file = os.path.join(PATH, '02-Unet')
model = load_model(model_file, custom_objects={'dice_coef':unet.dice_coef})

# %%
# Тестовые картинки
test_path = PATH + 'test1'
out_path = PATH + 'out1'

# !ls {test_path}
# Out:
# Paving_simple_colored_7183_diffuse_8K.jpg  Tactile_Paving_6872_diffuse_4K.jpg
# Roofing_corrida_8762_diffuse_4K.jpg	   Tactile_Paving_6872_height_4K.jpg
# Shingles_Hex_8174_diffuse.jpg		   Travertin_yellow_7349_diffuse_8K.jpg
# Stone_blocks_6371_diffuse_16K.jpg	   Wood_decking_5936_diffuse_6K.jpg

# %%
# Создадим список файлов
test_names= [os.path.join(test_path, file_name) for file_name in os.listdir(test_path)]

# %%
# Предикт и визуализация картинок из test
n = len(test_names)
fig, axs = plt.subplots(2, n, figsize=(25, 10))  

for i,file in enumerate(test_names):
    image = cv.imread(file)
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    # 
    pred = unet.pred_images(model, image, img_height, img_width) 
    #
    ones = np.ones((pred.shape[0], pred.shape[1], 3),dtype = np.uint8)
    image_pred = image.copy()
    image_pred[:, :, 0] = np.where(pred == 255, image_pred[:, :, 0], ones[:, :, 0] * 0)
    image_pred[:, :, 1] = np.where(pred == 255, image_pred[:, :, 1], ones[:, :, 0] * 255)
    image_pred[:, :, 2] = np.where(pred == 255, image_pred[:, :, 2], ones[:, :, 0] * 0)

    out_file = os.path.join(out_path, 'out_' + os.path.basename(file))
    print('Сохраняем результат {}'.format(out_file))
    ret = cv.imwrite(out_file, image_pred)
    if ret==False:
      print('Не удалось сохранить: {}'.format(file))

    axs[0,i].axis('off')
    axs[0,i].imshow(image)
    axs[0,i].set_title('original')

    axs[1,i].axis('off')
    axs[1,i].imshow(image_pred)
    axs[1,i].set_title('predict')
    
plt.show()
# Out:
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Tactile_Paving_6872_height_4K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Shingles_Hex_8174_diffuse.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Tactile_Paving_6872_diffuse_4K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Wood_decking_5936_diffuse_6K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Roofing_corrida_8762_diffuse_4K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Travertin_yellow_7349_diffuse_8K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Stone_blocks_6371_diffuse_16K.jpg
# Сохраняем результат /content/drive/MyDrive/my_data/Seams-segm/out1/out_Paving_simple_colored_7183_diffuse_8K.jpg

# %% [markdown]
# **Предикт на тестовых данных,  то есть на данных, которые нейронка не видела в процессе обучения**
